# %%
"""
Railway Inspection Data Processing Pipeline  —  Final Version
==============================================================
Handles all 8 defect file types:
  1. SOD exception          → sod_data
  2. Lip Flow               → lip_flow_data
  3. Vertical Wear          → vertical_wear_data
  4. Lateral Rail Wear      → lateral_wear_data
  5. Sleeper Defects        → sleeper_defects_data
  6. Rail Defects           → rail_defects_data
  7. Fittings               → fittings_data
  8. Ballast & Vegetation   → ballast_vegetation_data

All fixes included:
  FIX-1  Section (and all metadata) correctly extracted
           — header cells are split on \\n before joining
           — regex updated to allow lowercase, hyphens, colons
  FIX-2  Universal multi-level header detection (no S.No needed)
           — "Reporting Date" rows skipped even when they span multiple columns
           — Only non-last header rows are forward-filled (avoids column pollution)
           — Fully empty columns dropped after extraction
  FIX-3  Duplicate column names deduplicated (s_no → s_no, s_no_1 …)
  FIX-4  Append-if-exists / create-if-not SQLite behaviour
           — uses ALTER TABLE to add missing columns before each append
  FIX-5  Footer / summary rows removed (rows where lead cell is not numeric)
  FIX-6  Dataset type resolved from filename first, then header text
"""

import re
import sqlite3
import logging
import pandas as pd
from pathlib import Path

# ──────────────────────────────────────────────────────────────
# Configuration
# ──────────────────────────────────────────────────────────────
DB_PATH          = "railway.db"
BLOCK_TRIGGER    = "EXCEPTION REPORT"
HEADER_SCAN_ROWS = 12
LOG_FORMAT       = "%(asctime)s [%(levelname)s] %(message)s"

logging.basicConfig(level=logging.INFO, format=LOG_FORMAT)
log = logging.getLogger(__name__)


# ──────────────────────────────────────────────────────────────
# Dataset type map  (filename checked first → most reliable)
# ──────────────────────────────────────────────────────────────
DATASET_TYPE_MAP = [
    ("sod exception",           "sod_data"),
    ("sod_exception",           "sod_data"),
    ("lip flow",                "lip_flow_data"),
    ("lip_flow",                "lip_flow_data"),
    ("vertical wear",           "vertical_wear_data"),
    ("vertical_wear",           "vertical_wear_data"),
    ("lateral rail wear",       "lateral_wear_data"),
    ("lateral wear",            "lateral_wear_data"),
    ("lateral_wear",            "lateral_wear_data"),
    ("sleeper defect",          "sleeper_defects_data"),
    ("sleeper_defect",          "sleeper_defects_data"),
    ("sleeper",                 "sleeper_defects_data"),
    ("rail defect",             "rail_defects_data"),
    ("rail_defect",             "rail_defects_data"),
    ("fittings",                "fittings_data"),
    ("fitting",                 "fittings_data"),
    ("ballast and vegetation",  "ballast_vegetation_data"),
    ("ballast & vegetation",    "ballast_vegetation_data"),
    ("ballast_and_vegetation",  "ballast_vegetation_data"),
    ("ballast",                 "ballast_data"),
    ("vegetation",              "vegetation_data"),
    ("sod",                     "sod_data"),
    ("geometry",                "geometry_data"),
    ("gauge",                   "gauge_data"),
    ("squat",                   "squat_data"),
    ("corrugation",             "corrugation_data"),
    ("head check",              "head_check_data"),
]

# Patterns that identify metadata / non-header rows to skip
_SKIP_ROW_PATTERNS = re.compile(
    r"reporting\s*date|itms\s*reports?|^reporting|^iTMS",
    re.IGNORECASE,
)


# ──────────────────────────────────────────────────────────────
# Helpers
# ──────────────────────────────────────────────────────────────
def _is_numeric(val) -> bool:
    """Return True if val can be cast to float."""
    try:
        float(str(val).strip())
        return True
    except (ValueError, TypeError):
        return False


def _cell_lines(val) -> list:
    """Split a cell value on newlines, return non-empty stripped lines."""
    if pd.isna(val):
        return []
    return [ln.strip() for ln in str(val).split("\n") if ln.strip()]


def _populated(row: pd.Series) -> list:
    """Non-empty string values from a row."""
    return [
        str(v).strip()
        for v in row.values
        if pd.notna(v) and str(v).strip() not in ("", "nan")
    ]


def _is_skip_row(pop: list) -> bool:
    """
    Return True if this row should be ignored while building the header.
    Covers:
      • Rows where every cell matches a skip-pattern (Reporting Date, iTMS, …)
      • Single-cell rows with very long text (metadata / EXCEPTION REPORT cell)
    """
    if not pop:
        return True
    if all(_SKIP_ROW_PATTERNS.search(p) for p in pop):
        return True
    if len(pop) == 1 and len(pop[0]) > 50:
        return True
    return False


# ──────────────────────────────────────────────────────────────
# 1. detect_blocks
# ──────────────────────────────────────────────────────────────
def detect_blocks(df: pd.DataFrame) -> list:
    """
    Find every row containing EXCEPTION REPORT.
    Slice the sheet into one sub-DataFrame per block.
    Everything above the first trigger row is ignored.
    """
    trigger_rows = []
    for idx, row in df.iterrows():
        row_text = " ".join(str(v) for v in row.values if pd.notna(v))
        if BLOCK_TRIGGER.lower() in row_text.lower():
            trigger_rows.append(idx)

    if not trigger_rows:
        return []

    blocks = []
    for i, start in enumerate(trigger_rows):
        end = trigger_rows[i + 1] if i + 1 < len(trigger_rows) else df.index[-1] + 1
        block = df.loc[start : end - 1].reset_index(drop=True)
        blocks.append(block)

    log.info(f"  Detected {len(blocks)} block(s).")
    return blocks


# ──────────────────────────────────────────────────────────────
# 2. extract_metadata
# ──────────────────────────────────────────────────────────────
def extract_metadata(block: pd.DataFrame) -> dict:
    """
    FIX-1: Split every cell on \\n before joining into full_text.
    This exposes metadata embedded inside multi-line cells.
    All 8 file types store section, TRC No, Run Date etc. inside a
    single multi-line cell — splitting on \\n makes them regex-accessible.
    """
    lines = []
    for _, row in block.iloc[:HEADER_SCAN_ROWS].iterrows():
        for val in row.values:
            lines.extend(_cell_lines(val))

    full_text = " | ".join(lines)

    def find(pattern, default=""):
        m = re.search(pattern, full_text, re.IGNORECASE)
        return m.group(1).strip() if m else default

    # ── Full section string e.g. "Kalyan-Manmad Line: UP Line KM : 139 to 261"
    section_full = find(r"section[:\s]*([^\|]+?)(?:\s*\||$)")

    # section_name: everything up to the direction keyword
    section_name = ""
    m_name = re.search(
        r"^(.*?Line)\s*:\s*(?:UP|DN|Down|IInd|IIIrd|IVth|3rd|4th)\s",
        section_full, re.IGNORECASE
    )
    if m_name:
        section_name = m_name.group(1).strip()
    else:
        m_fb = re.search(r"^(.*?)(?:\s*KM\s*:|$)", section_full, re.IGNORECASE)
        section_name = m_fb.group(1).strip() if m_fb else section_full

    # line_direction: UP / DN / Down / IIIrd / IVth etc.
    line_direction = ""
    m_dir = re.search(
        r"\b(UP|DN|Down|IInd|IIIrd|IVth|3rd|4th)\s+Line",
        section_full, re.IGNORECASE
    )
    if m_dir:
        line_direction = m_dir.group(1).strip()

    km_range  = find(r"KM\s*:\s*([\d.]+\s*to\s*[\d.]+)")
    trc_no    = find(r"TRC\s*No\.?\s*:?\s*([A-Z0-9\-/]+)")
    run_date  = find(r"RUN\s*Date\s*:?\s*([0-9]{1,2}[-/\s]\w+[-/\s][0-9]{2,4})")
    run_no    = find(r"RUN\s*No\.?\s*:?\s*([^\s\|]+)")
    rail_side = find(r"\b(Left Rail|Right Rail|Left|Right|LH|RH)\b")
    defect    = find(r"DEFECTS[-\s]+([A-Z][A-Z\s&/]+?)(?:\s*\(|\s*\||$)")
    if not defect:
        defect = find(r"[Dd]efect\s*[=:]\s*([^\|\n]+)")

    return {
        "full_header_text": full_text,
        "section_name":     section_name,
        "line_direction":   line_direction,
        "km_range":         km_range,
        "trc_no":           trc_no,
        "run_date":         run_date,
        "run_no":           run_no,
        "defect":           defect,
        "rail_side":        rail_side,
    }


# ──────────────────────────────────────────────────────────────
# 3. extract_table
# ──────────────────────────────────────────────────────────────
def _build_multilevel_columns(header_rows: list, n_cols: int) -> list:
    """
    FIX-2: Combine multiple header rows into descriptive column names.

    Rules:
    • All rows EXCEPT the last are forward-filled (handles merged cells in
      grouping / section rows like "Location", "Component Defects" etc.).
    • The LAST row is NOT forward-filled — leaf-level sub-headers like
      "Km", "Meter" should not bleed into separator NaN columns.
    • Unique non-empty parts are joined with '_' per column position.

    Examples:
      Fittings  → location_km | location_block |
                  component_defects_left_rail_missing_loose_clip | …
      Sleeper   → location_km | location_block |
                  nos_of_affected_sleepers_broken_sleeper | …
      Rail Def  → s_no | location_km | location_meter |
                  value_of_defect_mm | … (NaN separator col dropped later)
    """
    # Pad all rows to n_cols
    padded = []
    for row_vals in header_rows:
        row = list(row_vals)
        row = row[:n_cols] + [None] * max(0, n_cols - len(row))
        padded.append(row)

    # Forward-fill all rows EXCEPT the last one
    ff_rows = []
    for idx, row in enumerate(padded):
        sr = pd.Series(row, dtype=object).replace({"": None, "nan": None})
        if idx < len(padded) - 1:   # not the last header row → forward-fill
            sr = sr.ffill()
        ff_rows.append(sr.tolist())

    # Build column name by collecting unique parts top-to-bottom
    result = []
    for col_idx in range(n_cols):
        parts, prev = [], None
        for row in ff_rows:
            val = row[col_idx] if col_idx < len(row) else None
            if val and str(val).strip() and str(val).strip().lower() != "nan":
                v = str(val).strip()
                if v != prev:
                    parts.append(v)
                    prev = v
        result.append("_".join(parts) if parts else f"col_{col_idx}")

    return result


def _find_header_and_data(block: pd.DataFrame):
    """
    FIX-2: Scan the block (starting after the EXCEPTION REPORT row) to
    separate metadata rows, table header rows, and data rows.

    Skips:
      • Single-cell long-text rows (metadata, EXCEPTION REPORT line itself)
      • Rows where every populated cell matches a skip pattern
        (Reporting Date, iTMS Reports — even when they span multiple columns)
      • Blank rows

    Collects rows as header rows until the first row whose FIRST non-empty
    cell is numeric → everything from that row onwards is data.

    Returns (list_of_header_row_value_lists, data_start_iloc_index).
    """
    header_rows = []
    data_start  = None

    for i in range(1, len(block)):          # row 0 is the trigger
        row = block.iloc[i]
        pop = _populated(row)

        if not pop:
            continue                        # blank row — skip

        if _is_skip_row(pop):
            continue                        # metadata / reporting-date — skip

        # First non-empty cell is numeric → data starts here
        if _is_numeric(pop[0]):
            data_start = i
            break

        header_rows.append(row.tolist())    # genuine header row

    return header_rows, data_start


def extract_table(block: pd.DataFrame):
    """
    Locate header rows and data rows; build a DataFrame with descriptive
    column names.  Returns None if no valid table is found.
    """
    header_rows, data_start = _find_header_and_data(block)

    if not header_rows or data_start is None:
        log.warning("  Could not locate table header or data — skipping block.")
        return None

    n_cols    = len(block.columns)
    col_names = _build_multilevel_columns(header_rows, n_cols)

    data_df = block.iloc[data_start:].reset_index(drop=True)

    # Align col_names width to DataFrame
    while len(col_names) < len(data_df.columns):
        col_names.append(f"col_{len(col_names)}")
    data_df.columns = col_names[: len(data_df.columns)]

    # FIX-5: Drop footer rows where the lead cell is not a real number.
    # Use .iloc[:, 0] (not column name) to avoid crash when duplicate col names exist
    # before deduplication (e.g. Rail Defects has two "S.No." columns).
    mask = data_df.iloc[:, 0].apply(_is_numeric)
    data_df = data_df[mask.values].reset_index(drop=True)

    return data_df if not data_df.empty else None


# ──────────────────────────────────────────────────────────────
# 4. clean_table
# ──────────────────────────────────────────────────────────────
def clean_table(df: pd.DataFrame) -> pd.DataFrame:
    """
    • Drop all-NaN rows and all-NaN columns.
    • Remove auto-generated / unnamed columns.
    • Standardise column names to snake_case.
    • FIX-3: Deduplicate column names.
    • FIX-5 second pass: keep only rows where lead column is numeric.
    """
    df = df.dropna(how="all").reset_index(drop=True)
    df = df.dropna(how="all", axis=1)           # drop fully-empty columns

    # Remove auto-generated columns
    df = df.loc[:, ~df.columns.str.contains(r"^Unnamed|^col_\d+$", na=False)]

    # snake_case
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(r"[^\w]", "_", regex=True)
        .str.replace(r"_+",   "_", regex=True)
        .str.strip("_")
    )
    df = df.loc[:, df.columns != ""]

    # FIX-3: Deduplicate column names
    seen, new_cols = {}, []
    for col in df.columns:
        if col in seen:
            seen[col] += 1
            new_cols.append(f"{col}_{seen[col]}")
        else:
            seen[col] = 0
            new_cols.append(col)
    df.columns = new_cols

    # FIX-5 second pass: enforce numeric lead column
    if len(df.columns) > 0:
        mask = df.iloc[:, 0].apply(_is_numeric)
        df = df[mask.values].reset_index(drop=True)

    return df


# ──────────────────────────────────────────────────────────────
# 5. detect_dataset_type
# ──────────────────────────────────────────────────────────────
def detect_dataset_type(metadata: dict, file_name: str = "") -> str:
    """
    FIX-6: Filename checked first, then header / defect text.
    Returns the matching table name or 'general_data'.
    """
    text = (
        file_name + " " +
        metadata.get("full_header_text", "") + " " +
        metadata.get("defect", "")
    ).lower()

    for keyword, table_name in DATASET_TYPE_MAP:
        if keyword in text:
            return table_name

    return "general_data"


# ──────────────────────────────────────────────────────────────
# 6. store_to_sql  — FIX-4: append-if-exists / create-if-not
# ──────────────────────────────────────────────────────────────
def _table_columns(conn: sqlite3.Connection, table_name: str) -> list:
    cur = conn.execute(
        "SELECT name FROM sqlite_master WHERE type='table' AND name=?",
        (table_name,),
    )
    if cur.fetchone() is None:
        return []
    return [r[1] for r in conn.execute(f"PRAGMA table_info('{table_name}')")]


def _add_missing_columns(conn: sqlite3.Connection, table_name: str, cols: list):
    existing = _table_columns(conn, table_name)
    for col in cols:
        if col not in existing:
            try:
                conn.execute(f"ALTER TABLE '{table_name}' ADD COLUMN '{col}' TEXT")
            except Exception as e:
                log.warning(f"  Could not add column '{col}': {e}")


def store_to_sql(df: pd.DataFrame, table_name: str, db_path: str = DB_PATH):
    """
    FIX-4: Append-if-exists / create-if-not.

    First run  → table does not exist  → pandas CREATE TABLE + INSERT.
    Later runs → table already exists  → ALTER TABLE for new cols + INSERT.

    Data is NEVER overwritten — only appended.
    """
    try:
        with sqlite3.connect(db_path) as conn:
            existing = _table_columns(conn, table_name)

            if not existing:
                df.to_sql(table_name, conn, if_exists="append", index=False)
            else:
                _add_missing_columns(conn, table_name, df.columns.tolist())
                existing = _table_columns(conn, table_name)
                common = [c for c in df.columns if c in existing]
                if not common:
                    log.warning(f"  No common columns for '{table_name}' — skipping.")
                    return
                df[common].to_sql(table_name, conn, if_exists="append", index=False)

        log.info(f"  Stored {len(df)} row(s) → '{table_name}'")

    except Exception as e:
        log.error(f"  DB write error for '{table_name}': {e}")


# ──────────────────────────────────────────────────────────────
# 7. process_folder  (main orchestrator)
# ──────────────────────────────────────────────────────────────
def process_folder(folder_path: str, db_path: str = DB_PATH):
    """
    Walk every .xlsx in folder_path.

    For each file → sheet → EXCEPTION REPORT block:
      1. extract_metadata   — section, TRC No, Run Date, Run No, defect, rail side
      2. extract_table      — universal multi-level header + data extraction
      3. clean_table        — snake_case columns, dedup, numeric filter, drop empty cols
      4. attach metadata    — section etc. added as columns on every row
      5. detect_dataset_type — filename-first lookup → table name
      6. store_to_sql       — append-if-exists / create-if-not
    """
    folder = Path(folder_path)
    xlsx_files = sorted(folder.glob("*.xlsx"))

    if not xlsx_files:
        log.warning(f"No .xlsx files found in: {folder_path}")
        return

    log.info(f"Found {len(xlsx_files)} Excel file(s) in '{folder_path}'.")

    total_blocks = 0
    total_rows   = 0
    summary: dict = {}

    for file_path in xlsx_files:
        log.info(f"\n{'='*60}")
        log.info(f"FILE: {file_path.name}")

        try:
            xl = pd.ExcelFile(file_path, engine="openpyxl")
        except Exception as e:
            log.error(f"  Cannot open '{file_path.name}': {e}")
            continue

        for sheet_name in xl.sheet_names:
            log.info(f"  Sheet: '{sheet_name}'")
            try:
                raw_df = xl.parse(sheet_name, header=None, dtype=str)
            except Exception as e:
                log.error(f"  Cannot read '{sheet_name}': {e}")
                continue

            if raw_df.empty:
                continue

            blocks = detect_blocks(raw_df)
            if not blocks:
                continue

            for b_idx, block in enumerate(blocks):
                log.info(f"  Block {b_idx + 1}/{len(blocks)} ...")
                total_blocks += 1
                try:
                    # ── 1. Metadata ───────────────────────────────────
                    metadata = extract_metadata(block)
                    log.info(
                        f"    section_name='{metadata['section_name']}'  "
                        f"trc='{metadata['trc_no']}'  "
                        f"date='{metadata['run_date']}'"
                    )

                    # ── 2. Table extraction ───────────────────────────
                    table_df = extract_table(block)
                    if table_df is None or table_df.empty:
                        log.warning(f"    No usable table — skipping.")
                        continue

                    # ── 3. Clean ──────────────────────────────────────
                    table_df = clean_table(table_df)
                    if table_df.empty:
                        log.warning(f"    Empty after cleaning — skipping.")
                        continue

                    # ── 4. Attach metadata columns ────────────────────
                    table_df["section_name"]   = metadata.get("section_name",   "")
                    table_df["line_direction"] = metadata.get("line_direction", "")
                    table_df["km_range"]       = metadata.get("km_range",       "")
                    table_df["trc_no"]         = metadata.get("trc_no",         "")
                    table_df["run_date"]       = metadata.get("run_date",       "")
                    table_df["run_no"]         = metadata.get("run_no",         "")
                    table_df["defect"]         = metadata.get("defect",         "")
                    table_df["rail_side"]      = metadata.get("rail_side",      "")
                    table_df["source_file"] = file_path.name
                    table_df["sheet_name"]  = sheet_name

                    # ── 5. Detect table name ──────────────────────────
                    tbl = detect_dataset_type(metadata, file_path.name)
                    log.info(f"    → table: '{tbl}'  rows: {len(table_df)}")

                    # ── 6. Write to SQLite ────────────────────────────
                    store_to_sql(table_df, tbl, db_path)

                    total_rows += len(table_df)
                    summary[tbl] = summary.get(tbl, 0) + len(table_df)

                except Exception as e:
                    log.error(f"    Block {b_idx + 1} failed: {e}", exc_info=True)

    # ── Final summary ──────────────────────────────────────────────────
    log.info(f"\n{'='*60}")
    log.info("PIPELINE COMPLETE")
    log.info(f"  Total blocks   : {total_blocks}")
    log.info(f"  Total rows     : {total_rows}")
    log.info(f"  Tables written :")
    for tbl, rows in sorted(summary.items()):
        log.info(f"    {tbl:<42} {rows:>6} rows")
    log.info(f"  Database       : {db_path}")
    log.info("=" * 60)


# ──────────────────────────────────────────────────────────────
# Entry point
# ──────────────────────────────────────────────────────────────
# AFTER (hardcoded path)
if __name__ == "__main__":

    input_folder = r"D:\\ENGINEER\\IndianRailwaysProject\\data"   # ← paste your folder path here
    output_db    = "railway.db"                         # ← DB will be created here

    process_folder(input_folder, output_db)
# Out:
# 2026-04-10 00:54:22,476 [INFO] Found 8 Excel file(s) in 'D:\\ENGINEER\\IndianRailwaysProject\\data'.
# 2026-04-10 00:54:22,476 [INFO]
# ============================================================
# 2026-04-10 00:54:22,477 [INFO] FILE: 1 SOD exception.xlsx
# 2026-04-10 00:54:22,855 [INFO]   Sheet: 'KYN-MMR UP'
# 2026-04-10 00:54:22,861 [INFO]   Sheet: 'KYN-MMR DN'
# 2026-04-10 00:54:22,864 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:22,864 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:22,866 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='29-Jul-2025'
# 2026-04-10 00:54:22,868 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:22,869 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:22,869 [INFO]   Sheet: 'MMR-CSN UP'
# 2026-04-10 00:54:22,871 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:22,872 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:22,872 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:22,873 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:22,873 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:22,874 [INFO]   Sheet: 'MMR-CSN DN'
# 2026-04-10 00:54:22,876 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:22,877 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:22,877 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:22,878 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:22,878 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:22,879 [INFO]   Sheet: 'MMR-CSN 3rd'
# 2026-04-10 00:54:22,943 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:22,943 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:22,944 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:22,953 [INFO]     → table: 'sod_data'  rows: 550
# 2026-04-10 00:54:22,962 [INFO]   Stored 550 row(s) → 'sod_data'
# 2026-04-10 00:54:22,962 [INFO]   Sheet: 'CSN-PC UP'
# 2026-04-10 00:54:22,964 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:22,965 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:22,966 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:22,967 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:22,967 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:22,967 [INFO]   Sheet: 'CSN-PC DN'
# 2026-04-10 00:54:22,983 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:22,983 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:22,985 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:22,990 [INFO]     → table: 'sod_data'  rows: 140
# 2026-04-10 00:54:22,996 [INFO]   Stored 140 row(s) → 'sod_data'
# 2026-04-10 00:54:22,997 [INFO]   Sheet: 'CSN-PC 3rd'
# 2026-04-10 00:54:23,024 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,025 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,026 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:23,030 [INFO]     → table: 'sod_data'  rows: 282
# 2026-04-10 00:54:23,036 [INFO]   Stored 282 row(s) → 'sod_data'
# 2026-04-10 00:54:23,037 [INFO]   Sheet: 'PC-JL UP'
# 2026-04-10 00:54:23,039 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,039 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,040 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:23,041 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:23,041 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:23,041 [INFO]   Sheet: 'PC-JL DN'
# 2026-04-10 00:54:23,067 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,068 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,069 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:23,074 [INFO]     → table: 'sod_data'  rows: 240
# 2026-04-10 00:54:23,080 [INFO]   Stored 240 row(s) → 'sod_data'
# 2026-04-10 00:54:23,080 [INFO]   Sheet: 'PC-JL 3rd'
# 2026-04-10 00:54:23,115 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,116 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,117 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:23,122 [INFO]     → table: 'sod_data'  rows: 360
# 2026-04-10 00:54:23,128 [INFO]   Stored 360 row(s) → 'sod_data'
# 2026-04-10 00:54:23,129 [INFO]   Sheet: 'JL-BSL UP'
# 2026-04-10 00:54:23,131 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,132 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,133 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:23,134 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:23,134 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:23,134 [INFO]   Sheet: 'JL-BSL DN'
# 2026-04-10 00:54:23,155 [INFO]   Sheet: 'JL-BSL 3rd'
# 2026-04-10 00:54:23,209 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,210 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,211 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:23,217 [INFO]     → table: 'sod_data'  rows: 566
# 2026-04-10 00:54:23,225 [INFO]   Stored 566 row(s) → 'sod_data'
# 2026-04-10 00:54:23,226 [INFO]   Sheet: 'JL-BSL 4th'
# 2026-04-10 00:54:23,287 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,288 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,289 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:23,295 [INFO]     → table: 'sod_data'  rows: 478
# 2026-04-10 00:54:23,302 [INFO]   Stored 478 row(s) → 'sod_data'
# 2026-04-10 00:54:23,302 [INFO]   Sheet: 'BSL-KNW UP'
# 2026-04-10 00:54:23,304 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,305 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,306 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:54:23,307 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:23,307 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:23,308 [INFO]   Sheet: 'BSL-KNW DN'
# 2026-04-10 00:54:23,310 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,311 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,312 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:54:23,313 [WARNING]   Could not locate table header or data — skipping block.
# 2026-04-10 00:54:23,313 [WARNING]     No usable table — skipping.
# 2026-04-10 00:54:23,314 [INFO]   Sheet: 'BSL-JM UP'
# 2026-04-10 00:54:23,339 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,340 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,341 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:23,347 [INFO]     → table: 'sod_data'  rows: 228
# 2026-04-10 00:54:23,355 [INFO]   Stored 228 row(s) → 'sod_data'
# 2026-04-10 00:54:23,355 [INFO]   Sheet: 'BSL-JM DN'
# 2026-04-10 00:54:23,378 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,379 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,380 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:23,385 [INFO]     → table: 'sod_data'  rows: 219
# 2026-04-10 00:54:23,393 [INFO]   Stored 219 row(s) → 'sod_data'
# 2026-04-10 00:54:23,394 [INFO]   Sheet: 'JM-AK UP'
# 2026-04-10 00:54:23,419 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,420 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,421 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:23,426 [INFO]     → table: 'sod_data'  rows: 265
# 2026-04-10 00:54:23,433 [INFO]   Stored 265 row(s) → 'sod_data'
# 2026-04-10 00:54:23,434 [INFO]   Sheet: 'JM-AK DN'
# 2026-04-10 00:54:23,494 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,495 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,496 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:23,501 [INFO]     → table: 'sod_data'  rows: 273
# 2026-04-10 00:54:23,510 [INFO]   Stored 273 row(s) → 'sod_data'
# 2026-04-10 00:54:23,511 [INFO]   Sheet: 'AK-MZR UP'
# 2026-04-10 00:54:23,533 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,534 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,536 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:23,542 [INFO]     → table: 'sod_data'  rows: 230
# 2026-04-10 00:54:23,548 [INFO]   Stored 230 row(s) → 'sod_data'
# 2026-04-10 00:54:23,549 [INFO]   Sheet: 'AK-MZR DN'
# 2026-04-10 00:54:23,573 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,573 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,575 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:23,580 [INFO]     → table: 'sod_data'  rows: 236
# 2026-04-10 00:54:23,586 [INFO]   Stored 236 row(s) → 'sod_data'
# 2026-04-10 00:54:23,587 [INFO]   Sheet: 'MZR-BD UP'
# 2026-04-10 00:54:23,597 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,597 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,598 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:23,604 [INFO]     → table: 'sod_data'  rows: 82
# 2026-04-10 00:54:23,609 [INFO]   Stored 82 row(s) → 'sod_data'
# 2026-04-10 00:54:23,610 [INFO]   Sheet: 'MZR-BD DN'
# 2026-04-10 00:54:23,631 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,631 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,633 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:23,638 [INFO]     → table: 'sod_data'  rows: 188
# 2026-04-10 00:54:23,645 [INFO]   Stored 188 row(s) → 'sod_data'
# 2026-04-10 00:54:23,645 [INFO]   Sheet: 'BD-PLO UP'
# 2026-04-10 00:54:23,649 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,649 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,650 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:23,654 [INFO]     → table: 'sod_data'  rows: 9
# 2026-04-10 00:54:23,660 [INFO]   Stored 9 row(s) → 'sod_data'
# 2026-04-10 00:54:23,661 [INFO]   Sheet: 'BD-PLO DN'
# 2026-04-10 00:54:23,665 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:23,665 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:23,666 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:23,670 [INFO]     → table: 'sod_data'  rows: 17
# 2026-04-10 00:54:23,675 [INFO]   Stored 17 row(s) → 'sod_data'
# 2026-04-10 00:54:23,676 [INFO]
# ============================================================
# 2026-04-10 00:54:23,676 [INFO] FILE: 2 lip flow exception.xlsx
# 2026-04-10 00:54:23,759 [INFO]   Sheet: 'KYN-MMR UP'
# 2026-04-10 00:54:23,889 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:23,892 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:23,898 [INFO]     section_name='Kalyan-Manmad Line'  trc='8001'  date='27-Dec-2025'
# 2026-04-10 00:54:23,928 [INFO]     → table: 'lip_flow_data'  rows: 10
# 2026-04-10 00:54:23,954 [INFO]   Stored 10 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:23,956 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:23,961 [INFO]     section_name='Kalyan-Manmad Line'  trc='8001'  date='27-Dec-2025'
# 2026-04-10 00:54:23,979 [INFO]     → table: 'lip_flow_data'  rows: 5
# 2026-04-10 00:54:24,000 [INFO]   Stored 5 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,003 [INFO]   Sheet: 'KYN-MMR DN'
# 2026-04-10 00:54:24,101 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:24,103 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:24,109 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='29-Jul-2025'
# 2026-04-10 00:54:24,133 [INFO]     → table: 'lip_flow_data'  rows: 5
# 2026-04-10 00:54:24,156 [INFO]   Stored 5 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,158 [INFO]   Sheet: 'MMR-CSN UP'
# 2026-04-10 00:54:24,261 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:24,263 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:24,268 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:24,297 [INFO]     → table: 'lip_flow_data'  rows: 3
# 2026-04-10 00:54:24,323 [INFO]   Stored 3 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,325 [INFO]   Sheet: 'MMR-CSN DN'
# 2026-04-10 00:54:24,338 [INFO]   Sheet: 'MMR-CSN 3rd'
# 2026-04-10 00:54:24,359 [INFO]   Sheet: 'CSN-PC UP'
# 2026-04-10 00:54:24,386 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:24,389 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:24,396 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:24,423 [INFO]     → table: 'lip_flow_data'  rows: 10
# 2026-04-10 00:54:24,444 [INFO]   Stored 10 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,445 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:24,450 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:24,475 [INFO]     → table: 'lip_flow_data'  rows: 1
# 2026-04-10 00:54:24,495 [INFO]   Stored 1 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,497 [INFO]   Sheet: 'CSN-PC DN'
# 2026-04-10 00:54:24,517 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:24,519 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:24,525 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:24,545 [INFO]     → table: 'lip_flow_data'  rows: 3
# 2026-04-10 00:54:24,568 [INFO]   Stored 3 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,571 [INFO]   Sheet: 'CSN-PC 3rd'
# 2026-04-10 00:54:24,583 [INFO]   Sheet: 'PC-JL UP'
# 2026-04-10 00:54:24,595 [INFO]   Sheet: 'PC-JL DN'
# 2026-04-10 00:54:24,606 [INFO]   Sheet: 'PC-JL 3rd'
# 2026-04-10 00:54:24,616 [INFO]   Sheet: 'JL-BSL UP'
# 2026-04-10 00:54:24,628 [INFO]   Sheet: 'JL-BSL DN'
# 2026-04-10 00:54:24,653 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:24,654 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:24,662 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:24,687 [INFO]     → table: 'lip_flow_data'  rows: 8
# 2026-04-10 00:54:24,712 [INFO]   Stored 8 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,714 [INFO]   Sheet: 'JL-BSL 3rd'
# 2026-04-10 00:54:24,728 [INFO]   Sheet: 'JL-BSL 4th'
# 2026-04-10 00:54:24,739 [INFO]   Sheet: 'BSL-KNW UP'
# 2026-04-10 00:54:24,753 [INFO]   Sheet: 'BSL-KNW DN'
# 2026-04-10 00:54:24,772 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:24,774 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:24,781 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:54:24,802 [INFO]     → table: 'lip_flow_data'  rows: 2
# 2026-04-10 00:54:24,822 [INFO]   Stored 2 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,824 [INFO]   Sheet: 'BSL-JM UP'
# 2026-04-10 00:54:24,861 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:24,864 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:24,871 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:24,901 [INFO]     → table: 'lip_flow_data'  rows: 12
# 2026-04-10 00:54:24,924 [INFO]   Stored 12 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,926 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:24,932 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:24,963 [INFO]     → table: 'lip_flow_data'  rows: 4
# 2026-04-10 00:54:24,985 [INFO]   Stored 4 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:24,986 [INFO]   Sheet: 'BSL-JM DN'
# 2026-04-10 00:54:24,996 [INFO]   Sheet: 'JM-AK UP'
# 2026-04-10 00:54:25,088 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:25,090 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:25,095 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:25,122 [INFO]     → table: 'lip_flow_data'  rows: 1
# 2026-04-10 00:54:25,146 [INFO]   Stored 1 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:25,148 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:25,154 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:25,178 [INFO]     → table: 'lip_flow_data'  rows: 1
# 2026-04-10 00:54:25,200 [INFO]   Stored 1 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:25,202 [INFO]   Sheet: 'JM-AK DN'
# 2026-04-10 00:54:25,216 [INFO]   Sheet: 'AK-MZR UP'
# 2026-04-10 00:54:25,227 [INFO]   Sheet: 'AK-MZR DN'
# 2026-04-10 00:54:25,240 [INFO]   Sheet: 'MZR-BD UP'
# 2026-04-10 00:54:25,262 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:25,264 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:25,269 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:25,294 [INFO]     → table: 'lip_flow_data'  rows: 1
# 2026-04-10 00:54:25,317 [INFO]   Stored 1 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:25,319 [INFO]   Sheet: 'MZR-BD DN'
# 2026-04-10 00:54:25,331 [INFO]   Sheet: 'BD-PLO UP'
# 2026-04-10 00:54:25,355 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:25,358 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:25,365 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:25,388 [INFO]     → table: 'lip_flow_data'  rows: 3
# 2026-04-10 00:54:25,405 [INFO]   Stored 3 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:25,406 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:25,412 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:25,441 [INFO]     → table: 'lip_flow_data'  rows: 1
# 2026-04-10 00:54:25,463 [INFO]   Stored 1 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:25,465 [INFO]   Sheet: 'BD-PLO DN'
# 2026-04-10 00:54:25,484 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:25,486 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:25,491 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:25,513 [INFO]     → table: 'lip_flow_data'  rows: 1
# 2026-04-10 00:54:25,532 [INFO]   Stored 1 row(s) → 'lip_flow_data'
# 2026-04-10 00:54:25,534 [INFO]
# ============================================================
# 2026-04-10 00:54:25,536 [INFO] FILE: 3 Vertical wear exception.xlsx
# 2026-04-10 00:54:29,409 [INFO]   Sheet: 'KYN-MMR UP'
# 2026-04-10 00:54:29,729 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:29,730 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:29,731 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:29,736 [INFO]     → table: 'vertical_wear_data'  rows: 6
# 2026-04-10 00:54:29,742 [INFO]   Stored 6 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:29,743 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:29,744 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:29,750 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:29,755 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:29,755 [INFO]   Sheet: 'KYN-MMR DN'
# 2026-04-10 00:54:29,853 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:29,853 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:29,855 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='29-Jul-2025'
# 2026-04-10 00:54:29,859 [INFO]     → table: 'vertical_wear_data'  rows: 7
# 2026-04-10 00:54:29,865 [INFO]   Stored 7 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:29,866 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:29,866 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='29-Jul-2025'
# 2026-04-10 00:54:29,871 [INFO]     → table: 'vertical_wear_data'  rows: 8
# 2026-04-10 00:54:29,884 [INFO]   Stored 8 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:29,886 [INFO]   Sheet: 'MMR-CSN UP'
# 2026-04-10 00:54:29,989 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:29,989 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:29,991 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:29,995 [INFO]     → table: 'vertical_wear_data'  rows: 6
# 2026-04-10 00:54:30,000 [INFO]   Stored 6 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,001 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,002 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:30,007 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:30,012 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,012 [INFO]   Sheet: 'MMR-CSN DN'
# 2026-04-10 00:54:30,133 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,133 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,135 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:30,140 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:30,144 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,144 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,145 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:30,152 [INFO]     → table: 'vertical_wear_data'  rows: 5
# 2026-04-10 00:54:30,156 [INFO]   Stored 5 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,157 [INFO]   Sheet: 'MMR-CSN 3rd'
# 2026-04-10 00:54:30,257 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,258 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,260 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:30,265 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:30,271 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,271 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,272 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:30,279 [INFO]     → table: 'vertical_wear_data'  rows: 7
# 2026-04-10 00:54:30,284 [INFO]   Stored 7 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,285 [INFO]   Sheet: 'CSN-PC UP'
# 2026-04-10 00:54:30,381 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,381 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,382 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:30,387 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:30,393 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,394 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,395 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:30,400 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:30,405 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,405 [INFO]   Sheet: 'CSN-PC DN'
# 2026-04-10 00:54:30,497 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,497 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,499 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:30,505 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:30,512 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,513 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,514 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:30,521 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:30,526 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,527 [INFO]   Sheet: 'CSN-PC 3rd'
# 2026-04-10 00:54:30,647 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,647 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,649 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:30,654 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:30,660 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,661 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,662 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:30,667 [INFO]     → table: 'vertical_wear_data'  rows: 6
# 2026-04-10 00:54:30,673 [INFO]   Stored 6 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,674 [INFO]   Sheet: 'PC-JL UP'
# 2026-04-10 00:54:30,815 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,816 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,817 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:30,822 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:30,829 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,830 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,831 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:30,836 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:30,843 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,844 [INFO]   Sheet: 'PC-JL DN'
# 2026-04-10 00:54:30,947 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:30,947 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:30,949 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:30,954 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:30,961 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,961 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:30,962 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:30,970 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:30,976 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:30,976 [INFO]   Sheet: 'PC-JL 3rd'
# 2026-04-10 00:54:31,083 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:31,084 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:31,085 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:31,090 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:31,095 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,096 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:31,097 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:31,101 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:31,105 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,106 [INFO]   Sheet: 'JL-BSL UP'
# 2026-04-10 00:54:31,204 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:31,205 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:31,205 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:31,210 [INFO]     → table: 'vertical_wear_data'  rows: 5
# 2026-04-10 00:54:31,218 [INFO]   Stored 5 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,218 [INFO]   Sheet: 'JL-BSL DN'
# 2026-04-10 00:54:31,369 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:31,370 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:31,372 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:31,378 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:31,384 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,384 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:31,385 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:31,392 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:31,399 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,400 [INFO]   Sheet: 'JL-BSL 3rd'
# 2026-04-10 00:54:31,512 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:31,513 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:31,514 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:31,520 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:31,528 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,529 [INFO]   Sheet: 'JL-BSL 4th'
# 2026-04-10 00:54:31,635 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:31,635 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:31,636 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:31,642 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:31,649 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,649 [INFO]   Sheet: 'BSL-KNW UP'
# 2026-04-10 00:54:31,748 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:31,749 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:31,750 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:54:31,755 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:31,763 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,763 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:31,765 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:54:31,770 [INFO]     → table: 'vertical_wear_data'  rows: 11
# 2026-04-10 00:54:31,775 [INFO]   Stored 11 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,776 [INFO]   Sheet: 'BSL-KNW DN'
# 2026-04-10 00:54:31,875 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:31,875 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:31,876 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:54:31,881 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:31,885 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,886 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:31,888 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:54:31,893 [INFO]     → table: 'vertical_wear_data'  rows: 12
# 2026-04-10 00:54:31,897 [INFO]   Stored 12 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:31,897 [INFO]   Sheet: 'BSL-JM UP'
# 2026-04-10 00:54:32,022 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:32,022 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:32,023 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:32,028 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:32,033 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,033 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:32,034 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:32,039 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:32,044 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,044 [INFO]   Sheet: 'BSL-JM DN'
# 2026-04-10 00:54:32,138 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:32,138 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:32,139 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:32,143 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:32,149 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,149 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:32,150 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:32,155 [INFO]     → table: 'vertical_wear_data'  rows: 7
# 2026-04-10 00:54:32,159 [INFO]   Stored 7 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,159 [INFO]   Sheet: 'JM-AK UP'
# 2026-04-10 00:54:32,251 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:32,252 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:32,253 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:32,258 [INFO]     → table: 'vertical_wear_data'  rows: 8
# 2026-04-10 00:54:32,265 [INFO]   Stored 8 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,265 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:32,267 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:32,271 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:32,275 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,276 [INFO]   Sheet: 'JM-AK DN'
# 2026-04-10 00:54:32,372 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:32,373 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:32,374 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:32,379 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:32,385 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,385 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:32,386 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:32,391 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:32,397 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,397 [INFO]   Sheet: 'AK-MZR UP'
# 2026-04-10 00:54:32,491 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:32,492 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:32,493 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:32,498 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:32,502 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,503 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:32,504 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:32,508 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:32,513 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,513 [INFO]   Sheet: 'AK-MZR DN'
# 2026-04-10 00:54:32,752 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:32,755 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:32,762 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:32,789 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:32,811 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,813 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:32,817 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:32,838 [INFO]     → table: 'vertical_wear_data'  rows: 3
# 2026-04-10 00:54:32,858 [INFO]   Stored 3 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:32,861 [INFO]   Sheet: 'MZR-BD UP'
# 2026-04-10 00:54:33,388 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:33,391 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:33,398 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:33,426 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:33,452 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:33,455 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:33,463 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:33,494 [INFO]     → table: 'vertical_wear_data'  rows: 4
# 2026-04-10 00:54:33,519 [INFO]   Stored 4 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:33,522 [INFO]   Sheet: 'MZR-BD DN'
# 2026-04-10 00:54:34,084 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:34,086 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:34,092 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:34,123 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:34,157 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:34,159 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:34,168 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:34,195 [INFO]     → table: 'vertical_wear_data'  rows: 2
# 2026-04-10 00:54:34,219 [INFO]   Stored 2 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:34,223 [INFO]   Sheet: 'BD-PLO UP'
# 2026-04-10 00:54:34,238 [INFO]   Sheet: 'BD-PLO DN'
# 2026-04-10 00:54:34,751 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:34,754 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:34,761 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:34,787 [INFO]     → table: 'vertical_wear_data'  rows: 1
# 2026-04-10 00:54:34,814 [INFO]   Stored 1 row(s) → 'vertical_wear_data'
# 2026-04-10 00:54:34,817 [INFO]
# ============================================================
# 2026-04-10 00:54:34,819 [INFO] FILE: 4 lateral rail wear.xlsx
# 2026-04-10 00:54:35,106 [INFO]   Sheet: 'KYN-MMR UP'
# 2026-04-10 00:54:35,382 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:35,385 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:35,395 [INFO]     section_name='Kalyan-Manmad Line'  trc='8001'  date='27-Dec-2025'
# 2026-04-10 00:54:35,425 [INFO]     → table: 'lateral_wear_data'  rows: 38
# 2026-04-10 00:54:35,460 [INFO]   Stored 38 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:35,462 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:35,469 [INFO]     section_name='Kalyan-Manmad Line'  trc='8001'  date='27-Dec-2025'
# 2026-04-10 00:54:35,499 [INFO]     → table: 'lateral_wear_data'  rows: 24
# 2026-04-10 00:54:35,520 [INFO]   Stored 24 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:35,522 [INFO]   Sheet: 'KYN-MMR DN'
# 2026-04-10 00:54:35,594 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:35,597 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:35,605 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='29-Jul-2025'
# 2026-04-10 00:54:35,635 [INFO]     → table: 'lateral_wear_data'  rows: 47
# 2026-04-10 00:54:35,661 [INFO]   Stored 47 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:35,665 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:35,675 [INFO]     section_name='Kalyan-Manmad Line'  trc='8002'  date='29-Jul-2025'
# 2026-04-10 00:54:35,708 [INFO]     → table: 'lateral_wear_data'  rows: 26
# 2026-04-10 00:54:35,733 [INFO]   Stored 26 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:35,735 [INFO]   Sheet: 'MMR-CSN UP-'
# 2026-04-10 00:54:35,769 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:35,772 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:35,779 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:35,806 [INFO]     → table: 'lateral_wear_data'  rows: 9
# 2026-04-10 00:54:35,835 [INFO]   Stored 9 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:35,838 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:35,845 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='27-Jul-2025'
# 2026-04-10 00:54:35,873 [INFO]     → table: 'lateral_wear_data'  rows: 4
# 2026-04-10 00:54:35,895 [INFO]   Stored 4 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:35,897 [INFO]   Sheet: 'MMR-CSN DN-'
# 2026-04-10 00:54:35,962 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:35,966 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:35,973 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:36,010 [INFO]     → table: 'lateral_wear_data'  rows: 5
# 2026-04-10 00:54:36,043 [INFO]   Stored 5 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,045 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:36,051 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:36,081 [INFO]     → table: 'lateral_wear_data'  rows: 7
# 2026-04-10 00:54:36,106 [INFO]   Stored 7 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,108 [INFO]   Sheet: 'MMR-CSN 3rd-'
# 2026-04-10 00:54:36,150 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:36,152 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:36,160 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:36,202 [INFO]     → table: 'lateral_wear_data'  rows: 1
# 2026-04-10 00:54:36,229 [INFO]   Stored 1 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,231 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:36,238 [INFO]     section_name='Manmad-Chalisgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:36,269 [INFO]     → table: 'lateral_wear_data'  rows: 11
# 2026-04-10 00:54:36,289 [INFO]   Stored 11 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,291 [INFO]   Sheet: 'CSN-PC UP-'
# 2026-04-10 00:54:36,352 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:36,355 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:36,362 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:36,392 [INFO]     → table: 'lateral_wear_data'  rows: 4
# 2026-04-10 00:54:36,418 [INFO]   Stored 4 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,422 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:36,429 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:36,463 [INFO]     → table: 'lateral_wear_data'  rows: 5
# 2026-04-10 00:54:36,489 [INFO]   Stored 5 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,491 [INFO]   Sheet: 'CSN-PC DN-'
# 2026-04-10 00:54:36,549 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:36,551 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:36,560 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:36,594 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:36,615 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,617 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:36,626 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:36,652 [INFO]     → table: 'lateral_wear_data'  rows: 5
# 2026-04-10 00:54:36,673 [INFO]   Stored 5 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,675 [INFO]   Sheet: 'CSN-PC 3 rd'
# 2026-04-10 00:54:36,729 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:36,731 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:36,736 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:36,764 [INFO]     → table: 'lateral_wear_data'  rows: 1
# 2026-04-10 00:54:36,787 [INFO]   Stored 1 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,790 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:36,795 [INFO]     section_name='Chalisgaon-Pachora Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:36,825 [INFO]     → table: 'lateral_wear_data'  rows: 6
# 2026-04-10 00:54:36,847 [INFO]   Stored 6 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,850 [INFO]   Sheet: 'PC-JL UP'
# 2026-04-10 00:54:36,881 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:36,883 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:36,891 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:36,923 [INFO]     → table: 'lateral_wear_data'  rows: 4
# 2026-04-10 00:54:36,950 [INFO]   Stored 4 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:36,952 [INFO]   Sheet: 'PC-JL DN'
# 2026-04-10 00:54:36,979 [INFO]   Detected 1 block(s).
# 2026-04-10 00:54:36,980 [INFO]   Block 1/1 ...
# 2026-04-10 00:54:36,987 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:54:37,013 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:37,026 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,027 [INFO]   Sheet: 'PC-JL 3rd'
# 2026-04-10 00:54:37,061 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:37,063 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:37,070 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:37,100 [INFO]     → table: 'lateral_wear_data'  rows: 1
# 2026-04-10 00:54:37,123 [INFO]   Stored 1 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,126 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:37,135 [INFO]     section_name='Pachora-Jalgaon Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:37,163 [INFO]     → table: 'lateral_wear_data'  rows: 3
# 2026-04-10 00:54:37,180 [INFO]   Stored 3 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,183 [INFO]   Sheet: 'JL-BSL UP'
# 2026-04-10 00:54:37,218 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:37,221 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:37,232 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:37,258 [INFO]     → table: 'lateral_wear_data'  rows: 6
# 2026-04-10 00:54:37,285 [INFO]   Stored 6 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,289 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:37,301 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8002'  date='26-Jul-2025'
# 2026-04-10 00:54:37,346 [INFO]     → table: 'lateral_wear_data'  rows: 4
# 2026-04-10 00:54:37,366 [INFO]   Stored 4 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,369 [INFO]   Sheet: 'JL-BSL DN'
# 2026-04-10 00:54:37,413 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:37,416 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:37,422 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:37,457 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:37,482 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,484 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:37,495 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8002'  date='30-Jul-2025'
# 2026-04-10 00:54:37,530 [INFO]     → table: 'lateral_wear_data'  rows: 3
# 2026-04-10 00:54:37,561 [INFO]   Stored 3 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,564 [INFO]   Sheet: 'JL-BSL 3rd'
# 2026-04-10 00:54:37,600 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:37,603 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:37,609 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:37,653 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:37,681 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,683 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:37,691 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:54:37,729 [INFO]     → table: 'lateral_wear_data'  rows: 1
# 2026-04-10 00:54:37,764 [INFO]   Stored 1 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,766 [INFO]   Sheet: 'JL-BSL 4th'
# 2026-04-10 00:54:37,789 [INFO]   Sheet: 'BSL-KNW UP'
# 2026-04-10 00:54:37,830 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:37,834 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:37,847 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:54:37,880 [INFO]     → table: 'lateral_wear_data'  rows: 7
# 2026-04-10 00:54:37,906 [INFO]   Stored 7 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,909 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:37,922 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:54:37,955 [INFO]     → table: 'lateral_wear_data'  rows: 13
# 2026-04-10 00:54:37,978 [INFO]   Stored 13 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:37,980 [INFO]   Sheet: 'BSL-KNW DN'
# 2026-04-10 00:54:38,015 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:38,018 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:38,025 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:54:38,057 [INFO]     → table: 'lateral_wear_data'  rows: 9
# 2026-04-10 00:54:38,084 [INFO]   Stored 9 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,087 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:38,094 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:54:38,122 [INFO]     → table: 'lateral_wear_data'  rows: 9
# 2026-04-10 00:54:38,146 [INFO]   Stored 9 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,147 [INFO]   Sheet: 'BSL-JM UP'
# 2026-04-10 00:54:38,177 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:38,180 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:38,188 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:38,217 [INFO]     → table: 'lateral_wear_data'  rows: 4
# 2026-04-10 00:54:38,241 [INFO]   Stored 4 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,243 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:38,248 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:38,279 [INFO]     → table: 'lateral_wear_data'  rows: 1
# 2026-04-10 00:54:38,305 [INFO]   Stored 1 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,308 [INFO]   Sheet: 'BSL-JM DN'
# 2026-04-10 00:54:38,348 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:38,352 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:38,361 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:38,387 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:38,411 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,414 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:38,423 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:38,455 [INFO]     → table: 'lateral_wear_data'  rows: 8
# 2026-04-10 00:54:38,478 [INFO]   Stored 8 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,480 [INFO]   Sheet: 'JM-AK UP'
# 2026-04-10 00:54:38,587 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:38,590 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:38,597 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:38,636 [INFO]     → table: 'lateral_wear_data'  rows: 8
# 2026-04-10 00:54:38,662 [INFO]   Stored 8 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,665 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:38,673 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:54:38,703 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:38,735 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,738 [INFO]   Sheet: 'JM-AK DN'
# 2026-04-10 00:54:38,769 [INFO]   Detected 2 block(s).
# 2026-04-10 00:54:38,772 [INFO]   Block 1/2 ...
# 2026-04-10 00:54:38,784 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:54:38,814 [INFO]     → table: 'lateral_wear_data'  rows: 2
# 2026-04-10 00:54:38,840 [INFO]   Stored 2 row(s) → 'lateral_wear_data'
# 2026-04-10 00:54:38,844 [INFO]   Block 2/2 ...
# 2026-04-10 00:54:38,850 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# ...
# 2026-04-10 00:55:41,922 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:41,935 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:55:41,964 [INFO]     → table: 'ballast_vegetation_data'  rows: 98
# 2026-04-10 00:55:41,994 [INFO]   Stored 98 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:41,997 [INFO]   Sheet: 'JL-BSL 3rd'
# 2026-04-10 00:55:42,905 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:42,907 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:42,914 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:55:42,941 [INFO]     → table: 'ballast_vegetation_data'  rows: 35
# 2026-04-10 00:55:42,963 [INFO]   Stored 35 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:42,965 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:42,971 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:55:43,003 [INFO]     → table: 'ballast_vegetation_data'  rows: 394
# 2026-04-10 00:55:43,045 [INFO]   Stored 394 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:43,049 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:43,057 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='30-Dec-2025'
# 2026-04-10 00:55:43,093 [INFO]     → table: 'ballast_vegetation_data'  rows: 65
# 2026-04-10 00:55:43,125 [INFO]   Stored 65 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:43,128 [INFO]   Sheet: 'JL-BSL 4th'
# 2026-04-10 00:55:43,778 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:43,781 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:43,789 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:55:43,813 [INFO]     → table: 'ballast_vegetation_data'  rows: 39
# 2026-04-10 00:55:43,837 [INFO]   Stored 39 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:43,840 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:43,846 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:55:43,874 [INFO]     → table: 'ballast_vegetation_data'  rows: 225
# 2026-04-10 00:55:43,899 [INFO]   Stored 225 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:43,902 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:43,908 [INFO]     section_name='Jalgaon-Bhusaval Line'  trc='8001'  date='31-Dec-2025'
# 2026-04-10 00:55:43,933 [INFO]     → table: 'ballast_vegetation_data'  rows: 84
# 2026-04-10 00:55:43,955 [INFO]   Stored 84 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:43,957 [INFO]   Sheet: 'BSL-KNW UP'
# 2026-04-10 00:55:45,560 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:45,562 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:45,571 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:55:45,605 [INFO]     → table: 'ballast_vegetation_data'  rows: 26
# 2026-04-10 00:55:45,632 [INFO]   Stored 26 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:45,633 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:45,644 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:55:45,673 [INFO]     → table: 'ballast_vegetation_data'  rows: 496
# 2026-04-10 00:55:45,703 [INFO]   Stored 496 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:45,705 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:45,713 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='09-Jan-2026'
# 2026-04-10 00:55:45,744 [INFO]     → table: 'ballast_vegetation_data'  rows: 1438
# 2026-04-10 00:55:45,785 [INFO]   Stored 1438 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:45,788 [INFO]   Sheet: 'BSL-KNW DN'
# 2026-04-10 00:55:47,805 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:47,806 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:47,808 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:55:47,821 [INFO]     → table: 'ballast_vegetation_data'  rows: 53
# 2026-04-10 00:55:47,842 [INFO]   Stored 53 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:47,845 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:47,849 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:55:47,881 [INFO]     → table: 'ballast_vegetation_data'  rows: 1068
# 2026-04-10 00:55:47,914 [INFO]   Stored 1068 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:47,916 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:47,922 [INFO]     section_name='Bhusaval-Khandwa Line'  trc='8002'  date='10-Jan-2026'
# 2026-04-10 00:55:47,952 [INFO]     → table: 'ballast_vegetation_data'  rows: 1333
# 2026-04-10 00:55:47,998 [INFO]   Stored 1333 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:48,001 [INFO]   Sheet: 'BSL-JM UP'
# 2026-04-10 00:55:48,796 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:48,797 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:48,800 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:48,814 [INFO]     → table: 'ballast_vegetation_data'  rows: 19
# 2026-04-10 00:55:48,830 [INFO]   Stored 19 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:48,832 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:48,836 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:48,848 [INFO]     → table: 'ballast_vegetation_data'  rows: 433
# 2026-04-10 00:55:48,865 [INFO]   Stored 433 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:48,868 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:48,872 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:48,887 [INFO]     → table: 'ballast_vegetation_data'  rows: 686
# 2026-04-10 00:55:48,905 [INFO]   Stored 686 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:48,907 [INFO]   Sheet: 'BSL-JM DN'
# 2026-04-10 00:55:49,570 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:49,572 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:49,580 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:49,611 [INFO]     → table: 'ballast_vegetation_data'  rows: 46
# 2026-04-10 00:55:49,635 [INFO]   Stored 46 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:49,638 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:49,644 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:49,669 [INFO]     → table: 'ballast_vegetation_data'  rows: 345
# 2026-04-10 00:55:49,697 [INFO]   Stored 345 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:49,699 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:49,705 [INFO]     section_name='Bhusaval-Jalamb Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:49,731 [INFO]     → table: 'ballast_vegetation_data'  rows: 546
# 2026-04-10 00:55:49,761 [INFO]   Stored 546 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:49,762 [INFO]   Sheet: 'JM-AK UP'
# 2026-04-10 00:55:50,598 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:50,601 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:50,607 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:50,638 [INFO]     → table: 'ballast_vegetation_data'  rows: 5
# 2026-04-10 00:55:50,659 [INFO]   Stored 5 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:50,660 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:50,662 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:50,696 [INFO]     → table: 'ballast_vegetation_data'  rows: 295
# 2026-04-10 00:55:50,738 [INFO]   Stored 295 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:50,740 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:50,752 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:50,782 [INFO]     → table: 'ballast_vegetation_data'  rows: 437
# 2026-04-10 00:55:50,814 [INFO]   Stored 437 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:50,815 [INFO]   Sheet: 'JM-AK DN'
# 2026-04-10 00:55:51,486 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:51,489 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:51,494 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:51,516 [INFO]     → table: 'ballast_vegetation_data'  rows: 30
# 2026-04-10 00:55:51,537 [INFO]   Stored 30 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:51,539 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:51,546 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:51,573 [INFO]     → table: 'ballast_vegetation_data'  rows: 237
# 2026-04-10 00:55:51,605 [INFO]   Stored 237 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:51,609 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:51,617 [INFO]     section_name='Jalamb-Akola Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:51,647 [INFO]     → table: 'ballast_vegetation_data'  rows: 453
# 2026-04-10 00:55:51,674 [INFO]   Stored 453 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:51,676 [INFO]   Sheet: 'AK-MZR UP'
# 2026-04-10 00:55:52,299 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:52,302 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:52,308 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:52,333 [INFO]     → table: 'ballast_vegetation_data'  rows: 2
# 2026-04-10 00:55:52,354 [INFO]   Stored 2 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:52,356 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:52,364 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:52,388 [INFO]     → table: 'ballast_vegetation_data'  rows: 186
# 2026-04-10 00:55:52,412 [INFO]   Stored 186 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:52,414 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:52,423 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:52,450 [INFO]     → table: 'ballast_vegetation_data'  rows: 271
# 2026-04-10 00:55:52,477 [INFO]   Stored 271 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:52,479 [INFO]   Sheet: 'AK-MZR DN'
# 2026-04-10 00:55:53,163 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:53,164 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:53,171 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:53,195 [INFO]     → table: 'ballast_vegetation_data'  rows: 6
# 2026-04-10 00:55:53,215 [INFO]   Stored 6 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:53,217 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:53,227 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:53,255 [INFO]     → table: 'ballast_vegetation_data'  rows: 178
# 2026-04-10 00:55:53,277 [INFO]   Stored 178 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:53,280 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:53,288 [INFO]     section_name='Akola-Murtajapur Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:53,313 [INFO]     → table: 'ballast_vegetation_data'  rows: 429
# 2026-04-10 00:55:53,339 [INFO]   Stored 429 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:53,341 [INFO]   Sheet: 'MZR-BD UP'
# 2026-04-10 00:55:53,969 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:53,971 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:53,978 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:54,004 [INFO]     → table: 'ballast_vegetation_data'  rows: 4
# 2026-04-10 00:55:54,027 [INFO]   Stored 4 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:54,030 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:54,036 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:54,061 [INFO]     → table: 'ballast_vegetation_data'  rows: 181
# 2026-04-10 00:55:54,085 [INFO]   Stored 181 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:54,086 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:54,094 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:54,118 [INFO]     → table: 'ballast_vegetation_data'  rows: 363
# 2026-04-10 00:55:54,147 [INFO]   Stored 363 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:54,149 [INFO]   Sheet: 'MZR-BD DN'
# 2026-04-10 00:55:54,944 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:54,947 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:54,953 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:54,984 [INFO]     → table: 'ballast_vegetation_data'  rows: 5
# 2026-04-10 00:55:55,008 [INFO]   Stored 5 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:55,010 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:55,016 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:55,041 [INFO]     → table: 'ballast_vegetation_data'  rows: 409
# 2026-04-10 00:55:55,061 [INFO]   Stored 409 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:55,063 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:55,070 [INFO]     section_name='Murtajapur-Badnera Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:55,091 [INFO]     → table: 'ballast_vegetation_data'  rows: 386
# 2026-04-10 00:55:55,117 [INFO]   Stored 386 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:55,119 [INFO]   Sheet: 'BD-PLO UP'
# 2026-04-10 00:55:55,615 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:55,616 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:55,624 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:55,649 [INFO]     → table: 'ballast_vegetation_data'  rows: 5
# 2026-04-10 00:55:55,678 [INFO]   Stored 5 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:55,680 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:55,685 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:55,715 [INFO]     → table: 'ballast_vegetation_data'  rows: 13
# 2026-04-10 00:55:55,736 [INFO]   Stored 13 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:55,738 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:55,742 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='26-Dec-2025'
# 2026-04-10 00:55:55,773 [INFO]     → table: 'ballast_vegetation_data'  rows: 6
# 2026-04-10 00:55:55,795 [INFO]   Stored 6 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:55,797 [INFO]   Sheet: 'BD-PLO DN'
# 2026-04-10 00:55:56,297 [INFO]   Detected 3 block(s).
# 2026-04-10 00:55:56,299 [INFO]   Block 1/3 ...
# 2026-04-10 00:55:56,306 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:56,329 [INFO]     → table: 'ballast_vegetation_data'  rows: 7
# 2026-04-10 00:55:56,350 [INFO]   Stored 7 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:56,352 [INFO]   Block 2/3 ...
# 2026-04-10 00:55:56,360 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:56,384 [INFO]     → table: 'ballast_vegetation_data'  rows: 14
# 2026-04-10 00:55:56,405 [INFO]   Stored 14 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:56,406 [INFO]   Block 3/3 ...
# 2026-04-10 00:55:56,413 [INFO]     section_name='Badnera-Pulgaon Line'  trc='8001'  date='03-Jan-2026'
# 2026-04-10 00:55:56,437 [INFO]     → table: 'ballast_vegetation_data'  rows: 24
# 2026-04-10 00:55:56,456 [INFO]   Stored 24 row(s) → 'ballast_vegetation_data'
# 2026-04-10 00:55:56,458 [INFO]
# ============================================================
# 2026-04-10 00:55:56,460 [INFO] PIPELINE COMPLETE
# 2026-04-10 00:55:56,462 [INFO]   Total blocks   : 304
# 2026-04-10 00:55:56,465 [INFO]   Total rows     : 33654
# 2026-04-10 00:55:56,468 [INFO]   Tables written :
# 2026-04-10 00:55:56,470 [INFO]     ballast_vegetation_data                     16529 rows
# 2026-04-10 00:55:56,472 [INFO]     fittings_data                                5509 rows
# 2026-04-10 00:55:56,473 [INFO]     lateral_wear_data                             324 rows
# 2026-04-10 00:55:56,477 [INFO]     lip_flow_data                                  71 rows
# 2026-04-10 00:55:56,478 [INFO]     rail_defects_data                            3206 rows
# 2026-04-10 00:55:56,481 [INFO]     sleeper_defects_data                         3472 rows
# 2026-04-10 00:55:56,483 [INFO]     sod_data                                     4363 rows
# 2026-04-10 00:55:56,485 [INFO]     vertical_wear_data                            180 rows
# 2026-04-10 00:55:56,488 [INFO]   Database       : railway.db
# 2026-04-10 00:55:56,490 [INFO] ============================================================
